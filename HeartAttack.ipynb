# %% [markdown]
# # *Importing Modules*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from matplotlib import pyplot as plt 
plt.style.use('ggplot')

# %% [markdown]
# # *Reading DF*

# %%
df = pd.read_csv(r'D:\CSV_Files\heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.rename(columns={'cp':'ChestPainType','trtbps': 'Resting blood pressure','chol':'Cholestoral','fbs':'fasting blood sugar','restecg':'Resting electrocardiographic results','thalachh':'Maximum heart rate','slp': 'Slope','caa': 'Number of major vessels','thall': 'Thalium Stress Test','exng': 'Exercise induced angina'},inplace=True)
df.head()
# Out:
#    age  sex  ChestPainType  Resting blood pressure  Cholestoral  \
# 0   63    1              3                     145          233
# 1   37    1              2                     130          250
# 2   41    0              1                     130          204
# 3   56    1              1                     120          236
# 4   57    0              0                     120          354
#
#    fasting blood sugar  Resting electrocardiographic results  \
# 0                    1                                     0
# 1                    0                                     1
# 2                    0                                     0
# 3                    0                                     1
# 4                    0                                     1
#
#    Maximum heart rate  Exercise induced angina  oldpeak  Slope  \
# 0                 150                        0      2.3      0
# 1                 187                        0      3.5      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   303 non-null    int64
#  1   sex                                   303 non-null    int64
#  2   ChestPainType                         303 non-null    int64
#  3   Resting blood pressure                303 non-null    int64
#  4   Cholestoral                           303 non-null    int64
#  5   fasting blood sugar                   303 non-null    int64
#  6   Resting electrocardiographic results  303 non-null    int64
#  7   Maximum heart rate                    303 non-null    int64
#  8   Exercise induced angina               303 non-null    int64
#  9   oldpeak                               303 non-null    float64
#  10  Slope                                 303 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# age                                     0
# sex                                     0
# ChestPainType                           0
# Resting blood pressure                  0
# Cholestoral                             0
# fasting blood sugar                     0
# Resting electrocardiographic results    0
# Maximum heart rate                      0
# Exercise induced angina                 0
# oldpeak                                 0
# Slope                                   0
# Number of major vessels                 0
# Thalium Stress Test                     0
# output                                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              age         sex  ChestPainType  Resting blood pressure  \
# count  302.00000  302.000000     302.000000              302.000000
# mean    54.42053    0.682119       0.963576              131.602649
# std      9.04797    0.466426       1.032044               17.563394
# min     29.00000    0.000000       0.000000               94.000000
# 25%     48.00000    0.000000       0.000000              120.000000
# 50%     55.50000    1.000000       1.000000              130.000000
# 75%     61.00000    1.000000       2.000000              140.000000
# max     77.00000    1.000000       3.000000              200.000000
#
#        Cholestoral  fasting blood sugar  Resting electrocardiographic results  \
# count   302.000000           302.000000                            302.000000
# mean    246.500000             0.149007                              0.526490
# std      51.753489             0.356686                              0.526027
# ...

# %%
df['sex']=df['sex'].astype('category')
df['ChestPainType']=df['ChestPainType'].astype('category')
df['fasting blood sugar']=df['fasting blood sugar'].astype('category')
df['Resting electrocardiographic results']=df['Resting electrocardiographic results'].astype('category')
df['Exercise induced angina']=df['Exercise induced angina'].astype('category')
df['Slope']=df['Slope'].astype('category')
df['Number of major vessels']=df['Number of major vessels'].astype('category')
df['Thalium Stress Test']=df['Thalium Stress Test'].astype('category')
df['output']=df['output'].astype('category')

# %%
df.describe() #there are skeweness in Cholestoral & Maximum heart rate & oldpeak
# Out:
#              age  Resting blood pressure  Cholestoral  Maximum heart rate  \
# count  302.00000              302.000000   302.000000          302.000000
# mean    54.42053              131.602649   246.500000          149.569536
# std      9.04797               17.563394    51.753489           22.903527
# min     29.00000               94.000000   126.000000           71.000000
# 25%     48.00000              120.000000   211.000000          133.250000
# 50%     55.50000              130.000000   240.500000          152.500000
# 75%     61.00000              140.000000   274.750000          166.000000
# max     77.00000              200.000000   564.000000          202.000000
#
#           oldpeak
# count  302.000000
# mean     1.043046
# std      1.161452
# min      0.000000
# 25%      0.000000
# 50%      0.800000
# 75%      1.600000
# max      6.200000

# %%
df.describe(include='category')
# Out:
#         sex  ChestPainType  fasting blood sugar  \
# count   302            302                  302
# unique    2              4                    2
# top       1              0                    0
# freq    206            143                  257
#
#         Resting electrocardiographic results  Exercise induced angina  Slope  \
# count                                    302                      302    302
# unique                                     3                        2      3
# top                                        1                        0      2
# freq                                     151                      203    141
#
#         Number of major vessels  Thalium Stress Test  output
# count                       302                  302     302
# unique                        5                    4       2
# top                           0                    2       1
# freq                        175                  165     164

# %%
df[df.select_dtypes(include=np.number).columns].corr()
# Out:
#                              age  Resting blood pressure  Cholestoral  \
# age                     1.000000                0.283121     0.207216
# Resting blood pressure  0.283121                1.000000     0.125256
# Cholestoral             0.207216                0.125256     1.000000
# Maximum heart rate     -0.395235               -0.048023    -0.005308
# oldpeak                 0.206040                0.194600     0.050086
#
#                         Maximum heart rate   oldpeak
# age                              -0.395235  0.206040
# Resting blood pressure           -0.048023  0.194600
# Cholestoral                      -0.005308  0.050086
# Maximum heart rate                1.000000 -0.342201
# oldpeak                          -0.342201  1.000000

# %%
numerical_columns=df.select_dtypes(include=np.number)
categorical_columns=df.select_dtypes(include='category')

# %% [markdown]
# # *Visualization*

# %%
# Set the style and context
sns.set(style="whitegrid", context="notebook")

# Create the figure and axes
plt.figure(figsize=(12, 10))

# First subplot: Distribution plot of Age
plt.subplot(2, 1, 1)
sns.histplot(df['age'], kde=True, bins=20)
plt.title('Distribution of Age', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Second subplot: Box plot of Age
plt.subplot(2, 1, 2)
sns.boxplot(x=df['age'])
plt.title('Box Plot of Age', fontsize=15)
plt.xlabel('Age', fontsize=12)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
df['age'].skew()
# Out:
# -0.2037432795959691

# %%
sns.histplot(data=df,x='age',hue='output')
# Out:
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# Data preparation
index = df['sex'].value_counts().index
values = df['sex'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of Sex Counts', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff'], startangle=140)
plt.title('Pie Chart of Sex Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
df['sex'].corr(df['output'])
# Out:
# -0.2836093577958625

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
# Data preparation
index = df['ChestPainType'].value_counts().index
values = df['ChestPainType'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of ChestPainType Counts', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of ChestPainType Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
df['output'].corr(df['ChestPainType'])
# Out:
# 0.432079591566407

# %%
# Set the style and context
sns.set(style="whitegrid", context="notebook")

# Create the figure and axes
plt.figure(figsize=(12, 10))

# First subplot: Distribution plot of Age
plt.subplot(2, 1, 1)
sns.histplot(df['Resting blood pressure'], kde=True, bins=20)
plt.title('Distribution of Resting blood pressure', fontsize=15)
plt.xlabel('Resting blood pressure', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Second subplot: Box plot of Age
plt.subplot(2, 1, 2)
sns.boxplot(x=df['Resting blood pressure'])
plt.title('Box Plot of Resting blood pressure', fontsize=15)
plt.xlabel('Resting blood pressure', fontsize=12)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
plt.scatter(df['Resting blood pressure'],df['output'])

# %%
# Data preparation
index = df['fasting blood sugar'].value_counts().index
values = df['fasting blood sugar'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of fasting blood sugar Counts', fontsize=15)
plt.xlabel('Sex', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of fasting blood sugar Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Data preparation
index = df['Resting electrocardiographic results'].value_counts().index
values = df['Resting electrocardiographic results'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of Resting electrocardiographic results Counts', fontsize=15)
plt.xlabel('Resting electrocardiographic results', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Resting electrocardiographic results Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Data preparation
index = df['Exercise induced angina'].value_counts().index
values = df['Exercise induced angina'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of Exercise induced angina Counts', fontsize=15)
plt.xlabel('Exercise induced angina', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Exercise induced angina Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Data preparation
index = df['Thalium Stress Test'].value_counts().index
values = df['Thalium Stress Test'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of Thalium Stress Test Counts', fontsize=15)
plt.xlabel('Thalium Stress Test', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Thalium Stress Test Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr()['output']
# Out:
# age                                    -0.221476
# sex                                    -0.283609
# ChestPainType                           0.432080
# Resting blood pressure                 -0.146269
# Cholestoral                            -0.081437
# fasting blood sugar                    -0.026826
# Resting electrocardiographic results    0.134874
# Maximum heart rate                      0.419955
# Exercise induced angina                -0.435601
# oldpeak                                -0.429146
# Slope                                   0.343940
# Number of major vessels                -0.408992
# Thalium Stress Test                    -0.343101
# output                                  1.000000
# Name: output, dtype: float64

# %%
# Set the style and context
sns.set(style="whitegrid", context="notebook")

# Create the figure and axes
plt.figure(figsize=(12, 10))

# First subplot: Distribution plot of Age
plt.subplot(2, 1, 1)
sns.histplot(df['Maximum heart rate'], kde=True, bins=20)
plt.title('Distribution of Maximum heart rate', fontsize=15)
plt.xlabel('Maximum heart rate', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Second subplot: Box plot of Age
plt.subplot(2, 1, 2)
sns.boxplot(x=df['Maximum heart rate'])
plt.title('Box Plot of Maximum heart rate', fontsize=15)
plt.xlabel('Maximum heart rate', fontsize=12)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
df['Maximum heart rate'].skew()
# Out:
# -0.5326712468229611

# %%
# Set the style and context
sns.set(style="whitegrid", context="notebook")

# Create the figure and axes
plt.figure(figsize=(12, 10))

# First subplot: Distribution plot of Age
plt.subplot(2, 1, 1)
sns.histplot(df['oldpeak'], kde=True, bins=20)
plt.title('Distribution of oldpeak', fontsize=15)
plt.xlabel('oldpeak', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Second subplot: Box plot of Age
plt.subplot(2, 1, 2)
sns.boxplot(x=df['oldpeak'])
plt.title('Box Plot of oldpeak', fontsize=15)
plt.xlabel('oldpeak', fontsize=12)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
from sklearn.preprocessing import PowerTransformer
transform=PowerTransformer(standardize=True)
df['oldpeak']=transform.fit_transform(df['oldpeak'].values.reshape(-1,1))
sns.distplot(df['oldpeak'])
df['oldpeak'].skew()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_1456\3117266381.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# 0.12191186965981805

# %%
df['Maximum heart rate']=df['Maximum heart rate'].apply(lambda x:x**2)
df['Maximum heart rate'].skew()
# Out:
# -0.15325293796874062

# %%
df['output'].value_counts()
# Out:
# output
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
# Data preparation
index = df['output'].value_counts().index
values = df['output'].value_counts().values

# Create the figure and axes
plt.figure(figsize=(14, 6))

# First subplot: Bar plot of sex counts
plt.subplot(1, 2, 1)
plt.bar(index, values, color='skyblue')
plt.title('Bar Plot of output Counts', fontsize=15)
plt.xlabel('output', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Second subplot: Pie chart of sex distribution
plt.subplot(1, 2, 2)
plt.pie(values, labels=index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of output Distribution', fontsize=15)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.distplot(df['Maximum heart rate'])
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_1456\3640189413.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Home\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Maximum heart rate', ylabel='Density'>

# %%
numerical_columns
# Out:
#      age  Resting blood pressure  Cholestoral  Maximum heart rate  oldpeak
# 0     63                     145          233                 150      2.3
# 1     37                     130          250                 187      3.5
# 2     41                     130          204                 172      1.4
# 3     56                     120          236                 178      0.8
# 4     57                     120          354                 163      0.6
# ..   ...                     ...          ...                 ...      ...
# 298   57                     140          241                 123      0.2
# 299   45                     110          264                 132      1.2
# 300   68                     144          193                 141      3.4
# 301   57                     130          131                 115      1.2
# 302   57                     130          236                 174      0.0
#
# [302 rows x 5 columns]

# %%
numerical_columns=numerical_columns.columns
categorical_columns=categorical_columns.columns
numerical_columns
# Out:
# Index(['age', 'Resting blood pressure', 'Cholestoral', 'Maximum heart rate',
#        'oldpeak'],
#       dtype='object')

# %%
for col in numerical_columns[:-1]:
    df[col]=df[col].apply(lambda x:(x-np.mean(df[col]))/np.std(df[col]))
df.describe()
# Out:
#                 age  Resting blood pressure   Cholestoral  Maximum heart rate  \
# count  3.020000e+02            3.020000e+02  3.020000e+02        3.020000e+02
# mean  -2.588070e-16           -7.058372e-16  8.822964e-18        3.058628e-16
# std    1.001660e+00            1.001660e+00  1.001660e+00        1.001660e+00
# min   -2.814192e+00           -2.144521e+00 -2.332210e+00       -2.706253e+00
# 25%   -7.107878e-01           -6.617119e-01 -6.870826e-01       -7.788704e-01
# 50%    1.195033e-01           -9.140084e-02 -1.161266e-01        5.496812e-02
# 75%    7.283833e-01            4.789102e-01  5.467629e-01        7.067136e-01
# max    2.499671e+00            3.900776e+00  6.145034e+00        2.714929e+00
#
#             oldpeak
# count  3.020000e+02
# mean   1.646953e-16
# std    1.001660e+00
# min   -1.164806e+00
# 25%   -1.164806e+00
# 50%    1.607821e-01
# 75%    8.140071e-01
# max    2.109682e+00

# %% [markdown]
# # *Modeling*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size= 0.2, random_state= 0)
model = LogisticRegression()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.8423236514522822

# %%
model.score(x_test,y_test)
# Out:
# 0.8852459016393442

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
#create new a knn model
knn2 = KNeighborsClassifier()
# Create a dictionary of all values we want to test for n_neighbors
param_grid = {'n_neighbors': np.arange(1, 25)}

# Use GridSearchCV to test all values for n_neighbors
knn_gscv = GridSearchCV(knn2, param_grid, cv=5)

# Fit model to data
knn_gscv.fit(x_train, y_train)

# Get the best parameters and the best score
print("Best Parameters:", knn_gscv.best_params_)
print("Best Score:", knn_gscv.best_score_)
# Out:
# Best Parameters: {'n_neighbors': 21}
# Best Score: 0.7967687074829931

# %%
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
# Out:
# 0.8340248962655602

# %%
knn.score(x_test,y_test)
# Out:
# 0.8688524590163934

# %%
from sklearn.svm import SVC
param_grid = {
    'C': [0.1, 1, 10, 100], 
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree': [2, 3, 4],  # used for 'poly' kernel
    'gamma': ['scale', 'auto']  # used for 'rbf', 'poly', and 'sigmoid' kernels
}

# Initialize the model
svc = SVC()

# Perform grid search
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the grid search
grid_search.fit(x_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)

# Train the final model with the best parameters
best_model = grid_search.best_estimator_
best_model.fit(x_train, y_train)

# Evaluate the model on the test set
y_pred = best_model.predict(x_test)
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Parameters: {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Best Cross-Validation Score: 0.8302721088435374
# Test Accuracy: 0.8688524590163934

# %%
svc=SVC(**best_params)
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
# Out:
# 0.8423236514522822

# %%
svc.score(x_test,y_test)
# Out:
# 0.8688524590163934

# %%
from sklearn.tree import DecisionTreeClassifier
parameters={'max_depth':range(3,10)}
clf_ = GridSearchCV(DecisionTreeClassifier(criterion='gini'), parameters)
clf_.fit(x_train,y_train)
tree_model = clf_.best_estimator_
print (clf_.best_score_, clf_.best_params_)
# Out:
# 0.7679421768707483 {'max_depth': 4}

# %%
decision_tree=DecisionTreeClassifier(max_depth=4)
decision_tree.fit(x_train,y_train)
decision_tree.score(x_test,y_test)
# Out:
# 0.8360655737704918

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=7)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.8524590163934426
